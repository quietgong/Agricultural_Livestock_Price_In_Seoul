# %%
# 데이터셋 불러오기

import pandas as pd
df = pd.read_csv('C:/Users/quiet/Agricultural_Livestock_Price_In_Seoul/생필품 농수축산물 가격 정보(2013~2020).csv', encoding='euc-kr', low_memory=False)

# %%
# 품목 이름 전처리

import re
regex = "\(.*\)|\s-\s.*"
arr=[]
for i in range(len(df)):
    arr.append(re.sub(regex, '', str(df['품목 이름'][i])))
df['tmp']=arr
df=df.drop(['품목 이름'], axis=1)
df.rename(columns = {'tmp' : '품목 이름'}, inplace = True)

# %%
# pandas 실수값 표현

pd.options.display.float_format = '{:.5f}'.format

# %%
# data summary
df.shape
df.head(3)
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348414 entries, 0 to 348413
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   일련번호               348414 non-null  int64
#  1   시장/마트 번호           348414 non-null  int64
#  2   시장/마트 이름           348414 non-null  object
#  3   품목 번호              348414 non-null  int64
#  4   실판매규격              348414 non-null  object
#  5   가격(원)              348414 non-null  int64
#  6   년도-월               348414 non-null  object
#  7   비고                 261337 non-null  object
#  8   시장유형 구분(시장/마트) 코드  348414 non-null  int64
#  9   시장유형 구분(시장/마트) 이름  348414 non-null  object
#  10  자치구 코드             348414 non-null  int64
#  11  자치구 이름             348414 non-null  object
#  12  점검일자               348414 non-null  object
#  13  품목 이름              348414 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 37.2+ MB
# ...

# %%
# 시장유형 구분(코드 1 : 전통시장, 코드 2 : 대형마트)

subset=df[['시장유형 구분(시장/마트) 코드','시장유형 구분(시장/마트) 이름']]
subset.describe()
# Out:
#        시장유형 구분(시장/마트) 코드
# count       348414.00000
# mean             1.50908
# std              0.49992
# min              1.00000
# 25%              1.00000
# 50%              2.00000
# 75%              2.00000
# max              2.00000

# %%
# 데이터 null값 확인

df.isnull().sum()
# Out:
# 일련번호                     0
# 시장/마트 번호                 0
# 시장/마트 이름                 0
# 품목 번호                    0
# 실판매규격                    0
# 가격(원)                    0
# 년도-월                     0
# 비고                   87077
# 시장유형 구분(시장/마트) 코드        0
# 시장유형 구분(시장/마트) 이름        0
# 자치구 코드                   0
# 자치구 이름                   0
# 점검일자                     0
# 품목 이름                    0
# dtype: int64

# %%
# 품목 이름이 Nan인 데이터 삭제

df.drop(348060,inplace=True)

# %%
# 품목 번호, 품목 이름에 따라 중복없이 출력

df[['품목 번호', '품목 이름']].drop_duplicates(keep='first').sort_values('품목 번호')
# Out:
#         품목 번호 품목 이름
# 348067     13    동태
# 4285       13   고등어
# 267        17    달걀
# 348061     18  돼지고기
# 58         18   닭고기
# ...       ...   ...
# 348063    320   닭고기
# 76555     320    달걀
# 107285    320    조기
# 77371     321    달걀
# 76827     323    달걀
#
# [130 rows x 2 columns]

# %%
# 중복, 잘못 표기되어 있는 데이터 전처리 (품목코드와 품목이름이 다른 데이터)

# %%
# pandas 출력 행 최대 100개로 설정

pd.set_option('display.max_rows', 100)

# %%
# 품목 번호, 품목 이름의 개수가 100개 미만인 항목들 tuple로 치환
counts=df.groupby('품목 번호')['품목 이름'].value_counts()
counts=counts.reset_index(name='count')
counts=counts[counts['count']<100]
subset = counts[['품목 번호', '품목 이름']]
tuples = [tuple(x) for x in subset.to_numpy()]

# %%
# 품목 번호, 품목 이름의 개수가 100개 미만인 행들을 인덱스를 통해 삭제
idx=[]
for row in df[['품목 번호', '품목 이름']].itertuples():
    if (row[1],row[2]) in tuples:
            idx.append(row[0])
df = df[~df.index.isin(idx)]

# %%
# 품목 번호, 품목 이름 중복 확인

df[['품목 번호', '품목 이름']].drop_duplicates(keep='first').sort_values('품목 번호')
# Out:
#        품목 번호   품목 이름
# 4285      13     고등어
# 267       17      달걀
# 58        18     닭고기
# 38        22      오이
# 37        23      상추
# 36        24      양파
# 35        25       무
# 50        26      배추
# 49        27       배
# 48        28      사과
# 16        50      사과
# 193       51       배
# 9         52    돼지고기
# 8         58     쇠고기
# 360       82     쇠고기
# 488       98     쇠고기
# 25        99    돼지고기
# 200      106     쇠고기
# 199      118   호박,중간
# 23       119      호박
# 130      125      배추
# 56       131     쇠고기
# 19       133       무
# 27       134      달걀
# 1068     135      조기
# 92       136      조기
# 21760    138     닭고기
# 12       144      조기
# 29       152      명태
# 113      170       배
# 315      171      달걀
# 466      175      배추
# 11       181      달걀
# 105      202    돼지고기
# 1968     237      사과
# 60296    244      사과
# 1969     248       배
# 10134    253     오징어
# 30       254     오징어
# 16516    255     오징어
# 14       256     오징어
# 1438     257     오징어
# ...

# %%
# 달걀 품목제거

df = df[~df['품목 이름'].str.contains("달걀", na=False, case=False)]

# %%
df.columns
# Out:
# Index(['일련번호', '시장/마트 번호', '시장/마트 이름', '품목 번호', '실판매규격', '가격(원)', '년도-월', '비고',
#        '시장유형 구분(시장/마트) 코드', '시장유형 구분(시장/마트) 이름', '자치구 코드', '자치구 이름', '점검일자',
#        '품목 이름'],
#       dtype='object')

# %%
# 각종 행, 열 수정 및 삭제
df=df.drop(['시장/마트 이름', '품목 번호', '일련번호', '시장/마트 번호','비고','년도-월', '시장유형 구분(시장/마트) 코드'], axis=1)
df=df[['실판매규격', '품목 이름', '가격(원)', '시장유형 구분(시장/마트) 이름', '자치구 코드', '자치구 이름', '점검일자']]
df.rename(columns = {'시장유형 구분(시장/마트) 이름' : '시장유형'}, inplace = True)

# %%
# 빈도수가 10,000개 이상인 데이터만 선별

df = df[df['품목 이름'].map(df['품목 이름'].value_counts())>=10000]

# %%
import warnings
warnings.filterwarnings(action='ignore')
import seaborn as sns
sns.boxplot(y = df['가격(원)'] );

# %%
df=df[df['가격(원)']<=50000]
df=df[df['가격(원)']>1000]

# %%
# 한글폰트 설정
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
font_location = 'C:/Windows/Fonts/malgunbd.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)

# %%
sns.boxplot(y = df['가격(원)'] );

# %%
df['품목 이름'].unique()
# Out:
# array(['사과', '배', '배추', '양파', '애호박', '쇠고기', '돼지고기', '닭고기', '명태', '오징어',
#        '고등어', '무', '상추', '오이', '조기'], dtype=object)

# %%
from matplotlib import rcParams

rcParams['figure.figsize'] = 15,8
sns.countplot(x='품목 이름', data=df)

# %%
# 데이터 개수가 다른 데이터들에 비해 적은 경우 삭제

df = df[~df['품목 이름'].str.contains("애호박", na=False, case=False)]
df = df[~df['품목 이름'].str.contains("상추", na=False, case=False)]
df = df[~df['품목 이름'].str.contains("오이", na=False, case=False)]

# %%
# 시각화

# %%
# 시간별 가격 변동 확인 목적
df['점검일자']= pd.to_datetime(df['점검일자'])
df['점검월']= df['점검일자'].dt.month
df['점검일자']=df['점검일자'].astype('str')
df['점검연월'] = df['점검일자'].str[:7]
df['점검년도']= df['점검일자'].str[:4]

# %%
# 전통시장 / 마트 간의 가격차이

result=df.groupby(['시장유형'])['가격(원)'].mean()
sns.barplot(x=result.index, y=result.values)

# %%
result=df.groupby(['품목 이름'])['가격(원)'].mean()
sns.barplot(x=result.index, y=result.values)

# %%
result=df.groupby(['점검연월'])['가격(원)'].mean()
sns.barplot(x=result.index, y=result.values)

# %%
result=df.groupby(['자치구 이름'])['가격(원)'].mean()
sns.barplot(x=result.index, y=result.values)

# %%
result=df.groupby(['점검월'])['가격(원)'].mean()
sns.barplot(x=result.index, y=result.values)

# %%
groups=df.groupby(['품목 이름', '점검년도'], as_index=False).mean()
plt.figure(figsize=(10, 5))
sns.lineplot(data=groups, x="점검년도", y="가격(원)", hue="품목 이름")
plt.legend(bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)

# %%
# 데이터 분석 (쇠고기 값 예측)

# %%
# 데이터셋 불러오기

import pandas as pd
df = pd.read_csv('C:/Users/quiet/Agricultural_Livestock_Price_In_Seoul/생필품 농수축산물 가격 정보(2013~2020).csv', encoding='euc-kr', low_memory=False)

df.drop(348060,inplace=True)

# 각종 행, 열 수정 및 삭제
df=df.drop(['시장/마트 이름', '품목 번호', '일련번호', '시장/마트 번호','비고','년도-월', '시장유형 구분(시장/마트) 코드'], axis=1)
df=df[['실판매규격', '품목 이름', '가격(원)', '시장유형 구분(시장/마트) 이름', '자치구 코드', '자치구 이름', '점검일자']]
df.rename(columns = {'시장유형 구분(시장/마트) 이름' : '시장유형'}, inplace = True)

# 시간별 가격 변동 확인 목적
df['점검일자']= pd.to_datetime(df['점검일자'])
df['점검월']= df['점검일자'].dt.month
df['점검일자']=df['점검일자'].astype('str')
df['점검연월'] = df['점검일자'].str[:7]
df['점검년도']= df['점검일자'].str[:4]

# %%
df_beef = df[df['품목 이름'].str.contains("한우")]
df_beef = df_beef[df_beef['실판매규격'].str.contains("600")]
df_beef.replace({'시장유형': {'전통시장': 0}}, inplace=True)
df_beef.replace({'시장유형': {'대형마트': 1}}, inplace=True)

# %%
df_beef.describe()
# Out:
#              가격(원)        시장유형       자치구 코드         점검월
# count  17924.00000 17924.00000  17924.00000 17924.00000
# mean   28373.77522     0.51356 427334.02142     7.03470
# std     7902.63362     0.49983 180139.25831     3.26795
# min        0.00000     0.00000 110000.00000     1.00000
# 25%    23940.00000     0.00000 290000.00000     5.00000
# 50%    27000.00000     1.00000 410000.00000     7.00000
# 75%    31695.00000     1.00000 560000.00000    10.00000
# max   260520.00000     1.00000 740000.00000    12.00000

# %%
df_beef['tmp']=pd.to_datetime(df_beef['점검일자'])-pd.to_datetime('2013-01-30')
df_beef['tmp']=df_beef['tmp'].astype("str")

# %%
df_beef['날짜차이']=df_beef['tmp'].str.split(" ", expand=True)[0]

# %%
df_beef.drop(['실판매규격','품목 이름','자치구 이름','점검년도','점검일자','점검연월','점검월','점검년도','tmp'],axis = 1, inplace = True)
df_beef = df_beef.astype('int64')

# %%
df_beef=df_beef[df_beef['가격(원)']<=200000]

# %%
# 가격 min-max 정규화

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_beef[['날짜차이']] = scaler.fit_transform(df_beef[['날짜차이']])

# %%
plt.scatter(x = '날짜차이', y = '가격(원)',
data = df_beef, s = 100, alpha = 0.3, edgecolor = 'white')
plt.title('날짜별 가격변동', fontsize = 16)
plt.ylabel('가격(원)', fontsize = 12)
plt.xlabel('날짜 차이', fontsize = 12)
plt.savefig('enginesize_co2.png')

# %%
from sklearn.model_selection import train_test_split
X_var = df_beef[['날짜차이']] # independent variable
y_var = df_beef['가격(원)'] # dependent variable
X_train, X_test, y_train, y_test = train_test_split(
X_var, y_var, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
yhat = lr.predict(X_test)

# %%
from termcolor import colored as cl
print(cl('R-Squared :', attrs = ['bold']),
lr.score(X_test, y_test))
# Out:
# R-Squared : 0.17007297209612016

# %%
import seaborn as sb
slr_slope = lr.coef_
slr_intercept = lr.intercept_
sb.scatterplot(x = '날짜차이', y = '가격(원)',data = df_beef, s = 150, alpha = 0.3, edgecolor = 'white')
plt.plot(df_beef['날짜차이'], slr_slope*df_beef['날짜차이'] + slr_intercept, color = 'r', linewidth = 3)
plt.title('Engine size vs C02 Emissions', fontsize = 16)
plt.ylabel('CO2 Emissions', fontsize = 12)
plt.xlabel('Engine Size', fontsize = 12)
plt.savefig('enginesize_co2_fit.png')

# %%
from sklearn.model_selection import train_test_split
X1_var = df_beef[['날짜차이','시장유형','자치구 코드',]]
y_var = df_beef['가격(원)'] # dependent variable
X_train, X_test, y_train, y_test = train_test_split(
X1_var,
y_var,
test_size = 0.3,
random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
yhat = lr.predict(X_test)

# %%
from termcolor import colored as cl
print(cl('R-Squared :', attrs = ['bold']),
lr.score(X_test, y_test))
# Out:
# R-Squared : 0.3218993971520797

# %%
sb.distplot(yhat, hist = False, color = 'r', label = 'Predicted Values')
sb.distplot(y_test, hist = False, color = 'b', label = 'Actual Values')
plt.title('Actual vs Predicted Values', fontsize = 16)
plt.xlabel('Values', fontsize = 12)
plt.ylabel('Frequency', fontsize = 12)
plt.legend(loc = 'upper left', fontsize = 13)
plt.savefig('ap.png')

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
training_points = df_beef.drop(columns=['가격(원)'])
training_labels = df_beef['가격(원)']
X_train, X_test, y_train, y_test = train_test_split(
training_points,
training_labels,
test_size=0.3,
random_state=4)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# %%
classifier = KNeighborsClassifier(n_neighbors = 5)
classifier.fit(X_train, y_train)
guesses = classifier.predict(X_test)
print(guesses)
print(confusion_matrix(y_test, guesses))
print(metrics.accuracy_score(y_test, guesses))

# %%
k_range = range(1, 50)
accuracy_scores = []
for k in k_range:
    classifier = KNeighborsClassifier(n_neighbors = k)
    classifier.fit(X_train, y_train)
    guesses = classifier.predict(X_test)
    accuracy_scores.append(metrics.accuracy_score(y_test, guesses))
print(accuracy_scores)
#Visualize the result of KNN accuracy with matplotlib
plt.plot(k_range, accuracy_scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Testing Accuracy')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
#Create copy of dataset.
df_model = df_beef.copy()
#Rescaling features age, trestbps, chol, thalach, oldpeak.
scaler = MinMaxScaler()
features = [['날짜','시장유형','자치구 코드']]
for feature in features:
    df_model[feature] = scaler.fit_transform(df_model[feature])
training_points = df_model.drop(columns=['가격(원)'])
training_labels = df_model['가격(원)']

# %%
classifier = KNeighborsClassifier(n_neighbors = 5)
classifier.fit(X_train, y_train)
guesses = classifier.predict(X_test)
print(guesses)
print(confusion_matrix(y_test, guesses))
print(metrics.accuracy_score(y_test, guesses))
